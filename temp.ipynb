# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
data = pd.read_csv('data/spreadspoke_scores.csv')
data['schedule_date'] = pd.to_datetime(data['schedule_date'])

# %%
data[data.schedule_playoff == False]
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0        1966-09-02             1966             1             False
# 1        1966-09-03             1966             1             False
# 2        1966-09-04             1966             1             False
# 3        1966-09-09             1966             2             False
# 4        1966-09-10             1966             1             False
# ...             ...              ...           ...               ...
# 13498    2023-01-08             2022            18             False
# 13499    2023-01-08             2022            18             False
# 13500    2023-01-08             2022            18             False
# 13501    2023-01-08             2022            18             False
# 13502    2023-01-08             2022            18             False
#
#                    team_home  score_home  score_away          team_away  \
# ...
